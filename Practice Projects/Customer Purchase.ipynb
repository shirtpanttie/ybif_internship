# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('https://raw.githubusercontent.com/YBIFoundation/Dataset/main/Customer%20Purchase.csv')

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Education   Review Purchased
# 0         1021   30  Female    School  Average        No
# 1         1022   68  Female        UG     Poor        No
# 2         1023   70  Female        PG     Good        No
# 3         1024   72  Female        PG     Good        No
# 4         1025   16  Female        UG  Average        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer ID  50 non-null     int64
#  1   Age          50 non-null     int64
#  2   Gender       50 non-null     object
#  3   Education    50 non-null     object
#  4   Review       50 non-null     object
#  5   Purchased    50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#        Customer ID        Age
# count     50.00000  50.000000
# mean    1045.50000  54.160000
# std       14.57738  25.658161
# min     1021.00000  15.000000
# 25%     1033.25000  30.250000
# 50%     1045.50000  57.000000
# 75%     1057.75000  74.000000
# max     1070.00000  98.000000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Education', 'Review', 'Purchased'], dtype='object')

# %%
df.shape
# Out:
# (50, 6)

# %%
pd.DataFrame({'unicos':df.nunique(),
              'missing': df.isna().sum()/df.count(),
              'tipo':df.dtypes})
# Out:
#              unicos  missing    tipo
# Customer ID      50      0.0   int64
# Age              41      0.0   int64
# Gender            2      0.0  object
# Education         3      0.0  object
# Review            3      0.0  object
# Purchased         2      0.0  object

# %%
x = df[['Customer ID', 'Age', 'Gender', 'Education', 'Review']]

# %%
x.shape
# Out:
# (50, 5)

# %%
x
# Out:
#     Customer ID  Age  Gender Education   Review
# 0          1021   30  Female    School  Average
# 1          1022   68  Female        UG     Poor
# 2          1023   70  Female        PG     Good
# 3          1024   72  Female        PG     Good
# 4          1025   16  Female        UG  Average
# 5          1026   31  Female    School  Average
# 6          1027   18    Male    School     Good
# 7          1028   60  Female    School     Poor
# 8          1029   65  Female        UG  Average
# 9          1030   74    Male        UG     Good
# 10         1031   98  Female        UG     Good
# 11         1032   74    Male        UG     Good
# 12         1033   51    Male    School     Poor
# 13         1034   57  Female    School  Average
# 14         1035   15    Male        PG     Poor
# 15         1036   75    Male        UG     Poor
# 16         1037   59    Male        UG     Poor
# 17         1038   22  Female        UG     Poor
# 18         1039   19    Male    School     Good
# 19         1040   97    Male        PG     Poor
# 20         1041   57  Female    School  Average
# 21         1042   32    Male        PG  Average
# 22         1043   18  Female        PG     Poor
# 23         1044   96  Female    School     Good
# 24         1045   16  Female        PG  Average
# 25         1046   57  Female    School     Good
# 26         1047   53  Female        PG     Poor
# 27         1048   69  Female        PG     Poor
# 28         1049   48    Male    School     Poor
# 29         1050   83  Female        UG  Average
# 30         1051   73    Male        UG  Average
# 31         1052   22  Female    School     Poor
# 32         1053   92    Male        UG  Average
# 33         1054   89  Female        PG     Good
# 34         1055   86    Male    School  Average
# 35         1056   74    Male    School     Poor
# 36         1057   34  Female        UG     Good
# 37         1058   94    Male        PG  Average
# 38         1059   45  Female    School     Good
# 39         1060   76    Male        PG     Poor
# 40         1061   39    Male    School     Good
# 41         1062   23    Male        PG     Good
# 42         1063   30  Female        PG     Good
# 43         1064   27    Male        PG     Poor
# 44         1065   77  Female        UG  Average
# 45         1066   61    Male        PG     Poor
# 46         1067   64  Female        PG     Poor
# 47         1068   38  Female        PG     Good
# 48         1069   39  Female        UG     Good
# 49         1070   25  Female        UG     Good

# %%
x.replace({"Gender":{"Male":0,"Female":1}},inplace=True)
x.replace({"Education":{"School":0,"UG":1,"PG":2}},inplace=True)
x.replace({"Review":{"Poor":0,"Average":1,"Good":2}},inplace=True)
x
# Out:
#     Customer ID  Age  Gender  Education  Review
# 0          1021   30       1          0       1
# 1          1022   68       1          1       0
# 2          1023   70       1          2       2
# 3          1024   72       1          2       2
# 4          1025   16       1          1       1
# 5          1026   31       1          0       1
# 6          1027   18       0          0       2
# 7          1028   60       1          0       0
# 8          1029   65       1          1       1
# 9          1030   74       0          1       2
# 10         1031   98       1          1       2
# 11         1032   74       0          1       2
# 12         1033   51       0          0       0
# 13         1034   57       1          0       1
# 14         1035   15       0          2       0
# 15         1036   75       0          1       0
# 16         1037   59       0          1       0
# 17         1038   22       1          1       0
# 18         1039   19       0          0       2
# 19         1040   97       0          2       0
# 20         1041   57       1          0       1
# 21         1042   32       0          2       1
# 22         1043   18       1          2       0
# 23         1044   96       1          0       2
# 24         1045   16       1          2       1
# 25         1046   57       1          0       2
# 26         1047   53       1          2       0
# 27         1048   69       1          2       0
# 28         1049   48       0          0       0
# 29         1050   83       1          1       1
# 30         1051   73       0          1       1
# 31         1052   22       1          0       0
# 32         1053   92       0          1       1
# 33         1054   89       1          2       2
# 34         1055   86       0          0       1
# 35         1056   74       0          0       0
# 36         1057   34       1          1       2
# 37         1058   94       0          2       1
# 38         1059   45       1          0       2
# 39         1060   76       0          2       0
# 40         1061   39       0          0       2
# 41         1062   23       0          2       2
# 42         1063   30       1          2       2
# 43         1064   27       0          2       0
# 44         1065   77       1          1       1
# 45         1066   61       0          2       0
# 46         1067   64       1          2       0
# 47         1068   38       1          2       2
# 48         1069   39       1          1       2
# 49         1070   25       1          1       2

# %%
y = df['Purchased']

# %%
y
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
# 5     Yes
# 6      No
# 7     Yes
# 8      No
# 9     Yes
# 10    Yes
# 11    Yes
# 12     No
# 13     No
# 14    Yes
# 15     No
# 16    Yes
# 17    Yes
# 18     No
# 19    Yes
# 20    Yes
# 21     No
# 22    Yes
# 23     No
# 24    Yes
# 25     No
# 26     No
# 27     No
# 28     No
# 29    Yes
# 30     No
# 31    Yes
# 32    Yes
# 33    Yes
# 34     No
# 35    Yes
# 36    Yes
# 37    Yes
# 38     No
# 39     No
# 40     No
# 41    Yes
# 42    Yes
# 43     No
# 44     No
# 45    Yes
# 46     No
# 47    Yes
# 48    Yes
# 49     No
# Name: Purchased, dtype: object

# %%
y.shape
# Out:
# (50,)

# %%
xtr,xte,ytr,yte = train_test_split(x,y,test_size=0.2,random_state=2529)

# %%
xtr,xte,ytr,yte
# Out:
# (    Customer ID  Age  Gender  Education  Review
#  6          1027   18       0          0       2
#  1          1022   68       1          1       0
#  12         1033   51       0          0       0
#  5          1026   31       1          0       1
#  26         1047   53       1          2       0
#  29         1050   83       1          1       1
#  16         1037   59       0          1       0
#  34         1055   86       0          0       1
#  44         1065   77       1          1       1
#  14         1035   15       0          2       0
#  17         1038   22       1          1       0
#  9          1030   74       0          1       2
#  31         1052   22       1          0       0
#  30         1051   73       0          1       1
#  4          1025   16       1          1       1
#  3          1024   72       1          2       2
#  18         1039   19       0          0       2
#  33         1054   89       1          2       2
#  10         1031   98       1          1       2
#  39         1060   76       0          2       0
#  2          1023   70       1          2       2
#  35         1056   74       0          0       0
#  28         1049   48       0          0       0
#  27         1048   69       1          2       0
#  22         1043   18       1          2       0
#  47         1068   38       1          2       2
#  7          1028   60       1          0       0
#  49         1070   25       1          1       2
#  13         1034   57       1          0       1
#  37         1058   94       0          2       1
#  40         1061   39       0          0       2
#  23         1044   96       1          0       2
#  25         1046   57       1          0       2
#  43         1064   27       0          2       0
#  21         1042   32       0          2       1
#  24         1045   16       1          2       1
#  8          1029   65       1          1       1
#  36         1057   34       1          1       2
#  15         1036   75       0          1       0
#  32         1053   92       0          1       1,
#      Customer ID  Age  Gender  Education  Review
#  38         1059   45       1          0       2
#  48         1069   39       1          1       2
#  41         1062   23       0          2       2
#  45         1066   61       0          2       0
#  42         1063   30       1          2       2
#  11         1032   74       0          1       2
#  19         1040   97       0          2       0
#  46         1067   64       1          2       0
#  20         1041   57       1          0       1
#  0          1021   30       1          0       1,
#  6      No
#  1      No
#  12     No
#  5     Yes
#  26     No
#  29    Yes
#  16    Yes
#  34     No
#  44     No
#  14    Yes
#  17    Yes
#  9     Yes
#  31    Yes
#  30     No
#  4      No
#  3      No
#  18     No
#  33    Yes
#  10    Yes
#  39     No
#  2      No
#  35    Yes
#  28     No
#  27     No
#  22    Yes
#  47    Yes
#  7     Yes
#  49     No
#  13     No
#  37    Yes
#  40     No
#  23     No
#  25     No
#  43     No
#  21     No
#  24    Yes
#  8      No
#  36    Yes
#  15     No
#  32    Yes
#  Name: Purchased, dtype: object,
#  38     No
#  48    Yes
#  41    Yes
#  45    Yes
#  42    Yes
#  11    Yes
#  19    Yes
#  46     No
#  20    Yes
#  0      No
#  Name: Purchased, dtype: object)

# %%
model = LogisticRegression(max_iter=10000)

# %%
model.fit(xtr,ytr)
# Out:
# LogisticRegression(max_iter=10000)

# %%
ypred = model.predict(xte)

# %%
ypred
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No'],
#       dtype=object)

# %%
accuracy_score(yte,ypred)
# Out:
# 0.2

# %%
confusion_matrix(yte,ypred)
# Out:
# array([[2, 1],
#        [7, 0]], dtype=int64)

# %%
confusion_matrix(yte,ypred)
# Out:
# array([[2, 1],
#        [7, 0]], dtype=int64)

# %%
print(classification_report(yte,ypred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.22      0.67      0.33         3
#          Yes       0.00      0.00      0.00         7
#
#     accuracy                           0.20        10
#    macro avg       0.11      0.33      0.17        10
# weighted avg       0.07      0.20      0.10        10
