# %%
#step1 import libraries
#step2 open files(csv)
#step3 define target(y) and features(x)
#step4 the data (x,y) are divided into 2 parts train(75%) and test(25%)(train test split)
# from sklearn.model_selection import train_test_split
#step 5 select model
#step6 train or fit the model
#step7 predict
# step 8 accuracy

# %%
import pandas as pd
df = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
df.describe(include='all')
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
df.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
df.shape
# Out:
# (40, 2)

# %%
y = df['Salary']

x = df[['Experience Years']]
y.shape,x.shape
# Out:
# ((40,), (40, 1))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2529)
# x_train.shape,x_test.shape,y_train.shape,y_test.shape
x_train
# Out:
#     Experience Years
# 17               4.1
# 12               3.7
# 1                1.2
# 6                2.5
# 28               6.5
# 31               7.9
# 34               8.7
# 20               4.7
# 4                2.0
# 3                1.5
# 18               4.3
# 26               6.0
# 2                1.3
# 22               5.1
# 35               9.0
# 7                2.9
# 39              10.5
# 30               7.1
# 10               3.2
# 0                1.1
# 9                3.2
# 13               3.8
# 5                2.2
# 37               9.6
# 23               5.3
# 25               5.9
# 21               4.9
# 24               5.5
# 8                3.0
# 36               9.5
# 15               4.0
# 32               8.2

# %% [markdown]
# error = actual value - predicted values
# best fit = the line which gives the minimum sum of error^2

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 26344.85810217697

# %%
model.coef_
# Out:
# array([9398.19785815])

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 90252.60353757,  59238.55060569, 106229.53989642,  63937.64953476,
#         68636.74846383, 123146.29604108,  84613.68482268,  62997.82974895])

# %%
x_test
# Out:
#     Experience Years
# 29               6.8
# 11               3.5
# 33               8.5
# 16               4.0
# 19               4.5
# 38              10.3
# 27               6.2
# 14               3.9

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.050339688879149136
